# %% [markdown]
# # Sistemas de Informacion - Practica 2

# %%
import cmi

# %% [markdown]
# ## Top visualizaciones

# %%
cmi.ej1_widgets()
# Out:
# Dropdown(description='Tipo:', options=('', 'Peliculas', 'Series'), value='')
# Dropdown(description='Subtipo:', disabled=True, options=(), value=None)
# IntSlider(value=10, continuous_update=False, description='Top N:', max=30, min=1)

# %%
cmi.ej1_display()

# %% [markdown]
# ## Audiencia por horas

# %%
cmi.ej2_widgets()
# Out:
# Dropdown(description='Año: ', options=('2024',), value='2024')
# Dropdown(description='Mes: ', options=('Anual', 'Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio'…

# %%
cmi.ej2_display()

# %% [markdown]
# ## Sistema de recomendacion basado en usuarios

# %%
cmi.ej3_widgets()
# Out:
# IntText(value=0, description='ID de usuario')

# %%
cmi.ej3()
# Out:
# El usuario mas parecido de 0(Aaron) es 185(Victor). La recomendacion es s1286(Vincenzo)

# %% [markdown]
# # Tipos de usuarios segun visualizaciones

# %%
cmi.ej4()
